# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in ./machine_learning/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./machine_learning/lib/python3.11/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in ./machine_learning/lib/python3.11/site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./machine_learning/lib/python3.11/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in ./machine_learning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./machine_learning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./machine_learning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./machine_learning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./machine_learning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in ./machine_learning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in ./machine_learning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./machine_learning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./machine_learning/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip available: 22.3 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('wine-class.csv')

# %%
df.shape
# Out:
# (178, 14)

# %%
df.head()
# Out:
#    class  alcohol   malic_acid   ash   alcalinity_of_ash   magnesium  \
# 0      1    14.23         1.71  2.43                15.6         127
# 1      1    13.20         1.78  2.14                11.2         100
# 2      1    13.16         2.36  2.67                18.6         101
# 3      1    14.37         1.95  2.50                16.8         113
# 4      1    13.24         2.59  2.87                21.0         118
#
#     total_phenols   flavanoids   nonflavanoid_phenols   proanthocyanins  \
# 0            2.80         3.06                   0.28              2.29
# 1            2.65         2.76                   0.26              1.28
# 2            2.80         3.24                   0.30              2.81
# 3            3.85         3.49                   0.24              2.18
# 4            2.80         2.69                   0.39              1.82
#
#     color_intensity   hue   od280/od315_of_diluted_wines   proline
# 0              5.64  1.04                           3.92      1065
# 1              4.38  1.05                           3.40      1050
# 2              5.68  1.03                           3.17      1185
# 3              7.80  0.86                           3.45      1480
# 4              4.32  1.04                           2.93       735

# %%
# input data
x = df.drop('class', axis = 1)

# output data
y = df['class']

# %%
sns.countplot(x = y)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
y.value_counts()
# Out:
# class
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
# Cross-validation
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, random_state=0, test_size=0.25)

# %%
x_train.shape
# Out:
# (133, 13)

# %%
x_test.shape
# Out:
# (45, 13)

# %%
# Import the class
from sklearn.naive_bayes import GaussianNB

# %%
# create the object
clf = GaussianNB()

# %%
# Train the algorithm
clf.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
# Prediction on unseen data
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9333333333333333

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.89      1.00      0.94        16
#            2       1.00      0.86      0.92        21
#            3       0.89      1.00      0.94         8
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.95      0.94        45
# weighted avg       0.94      0.93      0.93        45

# %%
new = [[3.24,2.59,2.87,21.0,118,2.80,2.69,0.39,1.82,4.32,1.04,2.93,735]]

# %%
clf.predict(new)[0]
# Out:
# np.int64(2)

# %%
new =[[13.4,4.6,2.86,25,112,1.98,0.96,0.27,1.11,8.5,0.67,1.92,630]]
clf.predict(new)[0]
# Out:
# np.int64(3)

# %%
clf.predict_proba(new)
# Out:
# array([[9.63029979e-19, 3.91964059e-17, 1.00000000e+00]])

# %%
import numpy as np
np.argmax(clf.predict_proba(new))
# Out:
# np.int64(2)

# %%
sum(clf.predict_proba(new)[0])
# Out:
# np.float64(1.0)
